# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Arseny Reider**
#
# My desired ocupation is Data Analysis for Public Health Organization

# %% [markdown]
# *I am interested in data science because I would like to make an impact on improving health services for general public.*

# %% [markdown]
# ### The code in the Cell 5 will provide the result of simpe addition.

# %%
2023+1974
# Out:
# 3997

# %% [markdown]
# - This is bulleted part for my project.

# %% [markdown]
# 1 This is numbered part for my project.

# %% [markdown]
# ![Jupyter%20Notebook.png](attachment:Jupyter%20Notebook.png)

# %% [markdown]
# Use this code and test all links! [link text](http//:url)
#
# [Clik here to IBM logo] (https://www.ibm.com/brand/experience-guides/developer/brand/logo/)
